# %% [markdown]
# ## Install important libraries

# %%
pip install requests pandas pyodbc sqlalchemy
# Out:
# Requirement already satisfied: requests in c:\users\dell\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: pyodbc in c:\users\dell\anaconda3\lib\site-packages (5.2.0)
# Requirement already satisfied: sqlalchemy in c:\users\dell\anaconda3\lib\site-packages (2.0.36)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\dell\anaconda3\lib\site-packages (from sqlalchemy) (4.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\dell\anaconda3\lib\site-packages (from sqlalchemy) (2.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Collect Weather Data Using a Public API

# %%
import requests
from datetime import datetime

# API Configuration
API_KEY = "0eb62c4c6c41a6aba80ac4292fd0213a" 
CITIES = [
    "Cairo", "London", "New York", "Tokyo", "Paris", "Berlin", "Moscow", "Dubai", 
    "Sydney", "Toronto", "Beijing", "Mumbai", "Rome", "Madrid", "Seoul", "Singapore", 
    "Los Angeles", "Chicago", "São Paulo", "Bangkok", "Istanbul", "Jakarta", "Lagos", 
    "Cape Town", "Buenos Aires", "Mexico City", "Mumbai", "Shanghai", "Moscow", "Delhi"]

BASE_URL = "http://api.openweathermap.org/data/2.5/weather"

# Function to fetch weather data for a city
def fetch_weather_data(city):
    try:
        url = f"{BASE_URL}?q={city}&appid={API_KEY}&units=metric"
        
        # Make the API request
        response = requests.get(url)
        response.raise_for_status()  
        weather_data = response.json()

        # Check if the required keys exist in the response
        if all(key in weather_data for key in ['name', 'main', 'weather']):
            data = {
                "city": weather_data["name"],
                "temperature": weather_data["main"]["temp"],
                "humidity": weather_data["main"]["humidity"],
                "weather": weather_data["weather"][0]["description"],
                "timestamp": datetime.utcfromtimestamp(weather_data["dt"]).strftime('%Y-%m-%d %H:%M:%S')  # Convert timestamp
            }
            return data
        else:
            print(f"Error: Unexpected API response format for {city}. Please check the API key and city name.")
            return None

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data for {city}: {e}")
        return None

# Fetch weather data for all cities
for city in CITIES:
    weather_data = fetch_weather_data(city)
    if weather_data:
        print(f"Weather Data for {city}:")
        print(weather_data)
    else:
        print(f"No data available for {city}.")
    print("-" * 40)  # Separator for readability
# Out:
# Weather Data for Cairo:
# {'city': 'Cairo', 'temperature': 20.42, 'humidity': 52, 'weather': 'broken clouds', 'timestamp': '2025-02-05 10:57:22'}
# ----------------------------------------
# Weather Data for London:
# {'city': 'London', 'temperature': 7.55, 'humidity': 83, 'weather': 'broken clouds', 'timestamp': '2025-02-05 11:00:22'}
# ----------------------------------------
# Weather Data for New York:
# {'city': 'New York', 'temperature': -2.49, 'humidity': 52, 'weather': 'overcast clouds', 'timestamp': '2025-02-05 11:00:19'}
# ----------------------------------------
# Weather Data for Tokyo:
# {'city': 'Tokyo', 'temperature': 3.74, 'humidity': 31, 'weather': 'few clouds', 'timestamp': '2025-02-05 11:05:10'}
# ----------------------------------------
# Weather Data for Paris:
# {'city': 'Paris', 'temperature': 5.16, 'humidity': 100, 'weather': 'fog', 'timestamp': '2025-02-05 10:54:53'}
# ----------------------------------------
# Weather Data for Berlin:
# {'city': 'Berlin', 'temperature': 2.03, 'humidity': 86, 'weather': 'overcast clouds', 'timestamp': '2025-02-05 10:54:18'}
# ----------------------------------------
# Weather Data for Moscow:
# {'city': 'Moscow', 'temperature': -0.67, 'humidity': 62, 'weather': 'overcast clouds', 'timestamp': '2025-02-05 11:00:35'}
# ----------------------------------------
# Weather Data for Dubai:
# {'city': 'Dubai', 'temperature': 23.96, 'humidity': 43, 'weather': 'clear sky', 'timestamp': '2025-02-05 10:54:55'}
# ----------------------------------------
# Weather Data for Sydney:
# {'city': 'Sydney', 'temperature': 23.22, 'humidity': 79, 'weather': 'overcast clouds', 'timestamp': '2025-02-05 11:05:11'}
# ----------------------------------------
# Weather Data for Toronto:
# {'city': 'Toronto', 'temperature': -8.44, 'humidity': 74, 'weather': 'overcast clouds', 'timestamp': '2025-02-05 10:56:47'}
# ----------------------------------------
# Weather Data for Beijing:
# {'city': 'Beijing', 'temperature': -2.06, 'humidity': 12, 'weather': 'clear sky', 'timestamp': '2025-02-05 11:01:51'}
# ----------------------------------------
# Weather Data for Mumbai:
# {'city': 'Mumbai', 'temperature': 27.99, 'humidity': 39, 'weather': 'smoke', 'timestamp': '2025-02-05 11:07:14'}
# ----------------------------------------
# Weather Data for Rome:
# {'city': 'Rome', 'temperature': 13.47, 'humidity': 94, 'weather': 'overcast clouds', 'timestamp': '2025-02-05 11:03:59'}
# ----------------------------------------
# Weather Data for Madrid:
# {'city': 'Madrid', 'temperature': 8.23, 'humidity': 59, 'weather': 'clear sky', 'timestamp': '2025-02-05 11:00:01'}
# ----------------------------------------
# Weather Data for Seoul:
# {'city': 'Seoul', 'temperature': -8.24, 'humidity': 53, 'weather': 'clear sky', 'timestamp': '2025-02-05 11:01:37'}
# ----------------------------------------
# Weather Data for Singapore:
# {'city': 'Singapore', 'temperature': 26.02, 'humidity': 77, 'weather': 'scattered clouds', 'timestamp': '2025-02-05 11:07:15'}
# ----------------------------------------
# Weather Data for Los Angeles:
# {'city': 'Los Angeles', 'temperature': 11.68, 'humidity': 93, 'weather': 'mist', 'timestamp': '2025-02-05 11:02:38'}
# ----------------------------------------
# Weather Data for Chicago:
# {'city': 'Chicago', 'temperature': -3.18, 'humidity': 77, 'weather': 'overcast clouds', 'timestamp': '2025-02-05 10:59:25'}
# ----------------------------------------
# Weather Data for São Paulo:
# {'city': 'São Paulo', 'temperature': 24.44, 'humidity': 80, 'weather': 'clear sky', 'timestamp': '2025-02-05 11:07:15'}
# ----------------------------------------
# Weather Data for Bangkok:
# {'city': 'Bangkok', 'temperature': 33.9, 'humidity': 41, 'weather': 'clear sky', 'timestamp': '2025-02-05 10:56:07'}
# ----------------------------------------
# Weather Data for Istanbul:
# {'city': 'Istanbul', 'temperature': 2.9, 'humidity': 49, 'weather': 'broken clouds', 'timestamp': '2025-02-05 10:55:22'}
# ----------------------------------------
# Weather Data for Jakarta:
# {'city': 'Jakarta', 'temperature': 30.69, 'humidity': 67, 'weather': 'scattered clouds', 'timestamp': '2025-02-05 11:03:20'}
# ----------------------------------------
# Weather Data for Lagos:
# {'city': 'Lagos', 'temperature': 33.25, 'humidity': 50, 'weather': 'scattered clouds', 'timestamp': '2025-02-05 11:06:03'}
# ----------------------------------------
# Weather Data for Cape Town:
# {'city': 'Cape Town', 'temperature': 21.96, 'humidity': 54, 'weather': 'overcast clouds', 'timestamp': '2025-02-05 10:59:03'}
# ----------------------------------------
# Weather Data for Buenos Aires:
# {'city': 'Buenos Aires', 'temperature': 23.03, 'humidity': 92, 'weather': 'moderate rain', 'timestamp': '2025-02-05 11:07:16'}
# ----------------------------------------
# Weather Data for Mexico City:
# {'city': 'Mexico City', 'temperature': 8.96, 'humidity': 87, 'weather': 'clear sky', 'timestamp': '2025-02-05 11:05:36'}
# ----------------------------------------
# Weather Data for Mumbai:
# {'city': 'Mumbai', 'temperature': 27.99, 'humidity': 39, 'weather': 'smoke', 'timestamp': '2025-02-05 11:07:14'}
# ----------------------------------------
# Weather Data for Shanghai:
# {'city': 'Shanghai', 'temperature': 5.92, 'humidity': 49, 'weather': 'clear sky', 'timestamp': '2025-02-05 11:00:02'}
# ----------------------------------------
# Weather Data for Moscow:
# {'city': 'Moscow', 'temperature': -0.67, 'humidity': 62, 'weather': 'overcast clouds', 'timestamp': '2025-02-05 11:00:35'}
# ----------------------------------------
# Weather Data for Delhi:
# {'city': 'Delhi', 'temperature': 22.05, 'humidity': 28, 'weather': 'haze', 'timestamp': '2025-02-05 11:04:09'}
# ----------------------------------------

# %% [markdown]
# # Connection to local database, and send data from Weather API

# %%
import pyodbc

# Connect to Azure SQL
conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=ZAHRAMO7Y\MYSERVER;' 
    'DATABASE=weather_db;'
    'Trusted_Connection=yes;'
)

cursor = conn.cursor()

# Insert weather data for all cities
for city in CITIES:
    weather_data = fetch_weather_data(city)
    if weather_data:
        print(f"Weather Data for {city}:")
        print(weather_data)
        # Insert weather data
        cursor.execute("""
            INSERT INTO weather (city, temperature, humidity, weather, timestamp)
            VALUES (?, ?, ?, ?, ?)""",
            (weather_data["city"], weather_data["temperature"], weather_data["humidity"], weather_data["weather"], weather_data["timestamp"])
        )
        print("Data inserted successfully!")
    else:
        print(f"No data available for {city}.")
    print("-" * 40)  # Separator for readability

conn.commit()
cursor.close()
conn.close()
# Out:
# Weather Data for Cairo:
# {'city': 'Cairo', 'temperature': 20.42, 'humidity': 52, 'weather': 'broken clouds', 'timestamp': '2025-02-05 10:57:22'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for London:
# {'city': 'London', 'temperature': 7.55, 'humidity': 83, 'weather': 'broken clouds', 'timestamp': '2025-02-05 11:00:22'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for New York:
# {'city': 'New York', 'temperature': -2.49, 'humidity': 52, 'weather': 'overcast clouds', 'timestamp': '2025-02-05 11:00:19'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Tokyo:
# {'city': 'Tokyo', 'temperature': 3.74, 'humidity': 31, 'weather': 'few clouds', 'timestamp': '2025-02-05 11:05:10'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Paris:
# {'city': 'Paris', 'temperature': 5.42, 'humidity': 99, 'weather': 'fog', 'timestamp': '2025-02-05 11:07:25'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Berlin:
# {'city': 'Berlin', 'temperature': 2.03, 'humidity': 86, 'weather': 'overcast clouds', 'timestamp': '2025-02-05 10:54:18'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Moscow:
# {'city': 'Moscow', 'temperature': -0.67, 'humidity': 62, 'weather': 'overcast clouds', 'timestamp': '2025-02-05 11:00:35'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Dubai:
# {'city': 'Dubai', 'temperature': 23.96, 'humidity': 43, 'weather': 'clear sky', 'timestamp': '2025-02-05 10:54:55'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Sydney:
# {'city': 'Sydney', 'temperature': 23.22, 'humidity': 79, 'weather': 'overcast clouds', 'timestamp': '2025-02-05 11:05:11'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Toronto:
# {'city': 'Toronto', 'temperature': -8.44, 'humidity': 74, 'weather': 'overcast clouds', 'timestamp': '2025-02-05 10:56:47'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Beijing:
# {'city': 'Beijing', 'temperature': -2.06, 'humidity': 12, 'weather': 'clear sky', 'timestamp': '2025-02-05 11:01:51'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Mumbai:
# {'city': 'Mumbai', 'temperature': 27.99, 'humidity': 39, 'weather': 'smoke', 'timestamp': '2025-02-05 11:07:14'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Rome:
# {'city': 'Rome', 'temperature': 13.47, 'humidity': 94, 'weather': 'overcast clouds', 'timestamp': '2025-02-05 11:03:59'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Madrid:
# {'city': 'Madrid', 'temperature': 8.23, 'humidity': 59, 'weather': 'clear sky', 'timestamp': '2025-02-05 11:00:01'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Seoul:
# {'city': 'Seoul', 'temperature': -8.24, 'humidity': 53, 'weather': 'clear sky', 'timestamp': '2025-02-05 11:01:37'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Singapore:
# {'city': 'Singapore', 'temperature': 26.02, 'humidity': 77, 'weather': 'scattered clouds', 'timestamp': '2025-02-05 11:07:15'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Los Angeles:
# {'city': 'Los Angeles', 'temperature': 11.68, 'humidity': 93, 'weather': 'mist', 'timestamp': '2025-02-05 11:02:38'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Chicago:
# {'city': 'Chicago', 'temperature': -3.18, 'humidity': 77, 'weather': 'overcast clouds', 'timestamp': '2025-02-05 10:59:25'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for São Paulo:
# {'city': 'São Paulo', 'temperature': 24.44, 'humidity': 80, 'weather': 'clear sky', 'timestamp': '2025-02-05 11:07:15'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Bangkok:
# {'city': 'Bangkok', 'temperature': 33.9, 'humidity': 41, 'weather': 'clear sky', 'timestamp': '2025-02-05 10:56:07'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Istanbul:
# {'city': 'Istanbul', 'temperature': 2.9, 'humidity': 49, 'weather': 'broken clouds', 'timestamp': '2025-02-05 10:55:22'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Jakarta:
# {'city': 'Jakarta', 'temperature': 30.69, 'humidity': 67, 'weather': 'scattered clouds', 'timestamp': '2025-02-05 11:03:20'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Lagos:
# {'city': 'Lagos', 'temperature': 33.25, 'humidity': 50, 'weather': 'scattered clouds', 'timestamp': '2025-02-05 11:06:03'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Cape Town:
# {'city': 'Cape Town', 'temperature': 21.96, 'humidity': 54, 'weather': 'overcast clouds', 'timestamp': '2025-02-05 10:59:03'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Buenos Aires:
# {'city': 'Buenos Aires', 'temperature': 23.03, 'humidity': 92, 'weather': 'moderate rain', 'timestamp': '2025-02-05 11:07:16'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Mexico City:
# {'city': 'Mexico City', 'temperature': 8.96, 'humidity': 87, 'weather': 'clear sky', 'timestamp': '2025-02-05 11:05:36'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Mumbai:
# {'city': 'Mumbai', 'temperature': 27.99, 'humidity': 39, 'weather': 'smoke', 'timestamp': '2025-02-05 11:07:14'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Shanghai:
# {'city': 'Shanghai', 'temperature': 5.92, 'humidity': 49, 'weather': 'clear sky', 'timestamp': '2025-02-05 11:00:02'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Moscow:
# {'city': 'Moscow', 'temperature': -0.67, 'humidity': 62, 'weather': 'overcast clouds', 'timestamp': '2025-02-05 11:00:35'}
# Data inserted successfully!
# ----------------------------------------
# Weather Data for Delhi:
# {'city': 'Delhi', 'temperature': 22.05, 'humidity': 28, 'weather': 'haze', 'timestamp': '2025-02-05 11:04:09'}
# Data inserted successfully!
# ----------------------------------------

# %% [markdown]
# # Transorm and clean data

# %%
import pandas as pd
from sqlalchemy import create_engine

# Create a SQLAlchemy engine
connection_string = (
    "mssql+pyodbc://ZAHRAMO7Y\MYSERVER/weather_db?"
    "driver=ODBC+Driver+17+for+SQL+Server&"
    "Trusted_Connection=yes"
)
engine = create_engine(connection_string)

# Query the database
query = "SELECT * FROM weather;"
df = pd.read_sql(query, engine)

# Convert timestamp
df["timestamp"] = pd.to_datetime(df["timestamp"])

# Convert temperature to Fahrenheit
df["temperature_f"] = df["temperature"] * 9/5 + 32

# Drop duplicate rows, ignoring the timestamp column
df = df.drop_duplicates(subset=["city", "temperature", "humidity", "weather"])

# Display the first 30 rows
print(df.head(30))
# Out:
#     id          city  temperature  humidity           weather  \
# 0    1         Cairo        16.42        67  scattered clouds
# 5    6        London         8.58        86   overcast clouds
# 6    7      New York         4.93        38        few clouds
# 7    8         Tokyo         1.51        55        few clouds
# 8    9         Paris         2.12        99               fog
# 9   10        Berlin        -1.24        89         clear sky
# 10  11        Moscow        -0.74        67   overcast clouds
# 11  12         Dubai        18.96        55         clear sky
# 12  13        Sydney        24.34        87         clear sky
# 13  14       Toronto        -5.76        68     broken clouds
# 14  15       Beijing        -8.06        24         clear sky
# 15  16        Mumbai        23.99        33             smoke
# 16  17          Rome        24.54        50         clear sky
# 17  18        Madrid         6.43        69         clear sky
# 18  19         Seoul       -12.24        72         clear sky
# 19  20     Singapore        23.96        91     moderate rain
# 20  21   Los Angeles        17.22        62        few clouds
# 21  22       Chicago        -4.20        77   overcast clouds
# 22  23     São Paulo        21.52        94        light rain
# 23  24       Bangkok        24.94        51         clear sky
# 24  25      Istanbul         2.90        56     broken clouds
# 25  26       Jakarta        25.51        86   overcast clouds
# 26  27         Lagos        28.04        73        few clouds
# 27  28     Cape Town        20.18        72         clear sky
# 28  29  Buenos Aires        28.11        62  scattered clouds
# 29  30   Mexico City        21.64        21  scattered clouds
# 31  32      Shanghai         0.92        86         clear sky
# 33  34         Delhi        14.05        94              mist
# 35  36        London         8.27        86     broken clouds
# 36  37      New York         4.70        39        few clouds
#
#                  timestamp  temperature_f
# 0  2025-02-04 23:08:20.300         61.556
# 5  2025-02-04 21:06:07.000         47.444
# 6  2025-02-04 21:17:49.000         40.874
# 7  2025-02-04 21:10:03.000         34.718
# 8  2025-02-04 21:09:39.000         35.816
# 9  2025-02-04 21:07:08.000         29.768
# 10 2025-02-04 21:13:41.000         30.668
# 11 2025-02-04 21:06:00.000         66.128
# 12 2025-02-04 21:16:33.000         75.812
# 13 2025-02-04 21:18:33.000         21.632
# 14 2025-02-04 21:12:10.000         17.492
# 15 2025-02-04 21:19:10.000         75.182
# 16 2025-02-04 21:09:35.000         76.172
# 17 2025-02-04 21:15:11.000         43.574
# 18 2025-02-04 21:19:10.000          9.968
# 19 2025-02-04 21:15:00.000         75.128
# 20 2025-02-04 21:14:23.000         62.996
# 21 2025-02-04 21:05:42.000         24.440
# 22 2025-02-04 21:18:18.000         70.736
# 23 2025-02-04 21:13:29.000         76.892
# 24 2025-02-04 21:15:59.000         37.220
# 25 2025-02-04 21:17:21.000         77.918
# 26 2025-02-04 21:16:38.000         82.472
# 27 2025-02-04 21:14:01.000         68.324
# 28 2025-02-04 21:12:28.000         82.598
# 29 2025-02-04 21:15:41.000         70.952
# 31 2025-02-04 21:19:13.000         33.656
# 33 2025-02-04 21:19:13.000         57.290
# 35 2025-02-04 21:36:36.000         46.886
# 36 2025-02-04 21:30:00.000         40.460
